# %%
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.document_loaders import BSHTMLLoader # BeautifulSoup HTML Loader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.chains.summarize import load_summarize_chain
from langchain_community.document_loaders import BSHTMLLoader # <--- HTML LOADER
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

# %%
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = os.environ.get('LANGCHAIN_API_KEY')

# %%
os.environ["GOOGLE_API_KEY"] = os.environ.get('GOOGLE_GEMNI_API_KEY')

# %%
HTML_FILE_PATH = 'Source_Material/Example_game.html'
GENERATION_MODEL_NAME = "gemini-2.5-flash-preview-05-20"

# %%
LLM = ChatGoogleGenerativeAI(
    model=GENERATION_MODEL_NAME,
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
code_LLM = ChatGoogleGenerativeAI(
    model=GENERATION_MODEL_NAME,
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
# --- 1. Load Raw HTML and Extract Text ---
print(f"1. Processing HTML from '{HTML_FILE_PATH}'...")
raw_html_content = ""
extracted_text_content = ""
try:
    with open(HTML_FILE_PATH, 'r', encoding='utf-8') as f:
        raw_html_content = f.read()

    from bs4 import BeautifulSoup
    soup = BeautifulSoup(raw_html_content, 'html.parser')
    for unwanted_tag in soup(["script", "style", "nav", "footer", "aside"]): # Customize as needed
        unwanted_tag.decompose()
    extracted_text_content = soup.get_text(separator='\n', strip=True)
except Exception as e:
    print(f"🔴 Error processing HTML: {e}")
    exit()
# Out:
# 1. Processing HTML from 'Source_Material/Example_game.html'...

# %%
print(f"   Raw HTML length (chars): {len(raw_html_content)}")
print(f"   Extracted text length (chars): {len(extracted_text_content)}")
# Out:
#    Raw HTML length (chars): 165650
#    Extracted text length (chars): 29744

# %%
interpreter_template = """You are a business analyst, an expert at interpreting stakeholders and translating them to technical requirements. You will do three things before responding
1. Take in the question and determine the best visualization to go along with the question.
2. Come up with the best way to extract the data necessary from the given file, for example, writing Python code to parse an HTML file.
3. Ensure that the data needed for the visualization is in the given file.

After evaluating the question on the question. Given specific details on the approach the engineer should take in order to write the Python code necessary for the visualization.

Provided a description of the purpose and pseudo code for the engineer.

**DO NOT WRITE ANY CODE**

Given File:
---
{raw_html_source}
---

User Question: {question}

**DO NOT WRITE ANY CODE**
Content Answer:"""
interpreter_prompt = PromptTemplate.from_template(interpreter_template)
interpreter_chain = (
    {
        "raw_html_source": RunnableLambda(lambda x: raw_html_content), # Always provide full extracted text
        "question": RunnablePassthrough() # Pass the original question
    }
    | interpreter_prompt
    | LLM
    | StrOutputParser()
)

# %%
engineer_template = """You are an expert python software engineer, you specialize in extracting data and visualizations. The only output given should be a python code block. 
You will get technical requirements from a business analyst.

**IMPORTANT INSTRUCTIONS:**
-   **DO NOT include the provided 'Raw HTML Source Code' as a string literal within the generated Python script.**
-   Assume the HTML content will be loaded into a variable named `html_content` within the Python script. Your script should operate on this `html_content` variable.
-   Provide only the Python code block enclosed in ```python ... ```.
-   The script should be runnable if the `html_content` variable is pre-populated with the HTML.
-   The script should run and create the visualization without any additions such as calling a function.
-   Use HTML_FILE_PATH as an existing variable for the HTML file, assume this variable is already set and does not need to be defined.
-   Open the HTML file with open(HTML_FILE_PATH, encoding="utf-8") as f: soup = BeautifulSoup(f, "lxml") method to open HTML files **DO NOT COMMENT IT OUT**.
-   When getting values from pandas columns always use .values, for example, df['column_name'].values.

**IMPORTANT INFORMATION:**
-   Pandas version being used is 2.1.4.
-   matplotlib version being used is 3.5.1.
-   BeautifulSoup version being used is 4.11.1.

Technical Requirements:
---
{technical_requirements}
---

Given File:
---
{raw_html_source}
---

Code Block:"""
engineer_template_prompt = PromptTemplate.from_template(engineer_template)
engineer_prompt_chain = (
    {
        "raw_html_source": RunnableLambda(lambda x: raw_html_content), # Always provide full extracted text
        "technical_requirements": RunnablePassthrough() # Pass the original question
    }
    | engineer_template_prompt
    | code_LLM
    | StrOutputParser()
)

# %%
def ask_intelligent_assistant(user_question, code=False):
    if code:
        response = engineer_prompt_chain.invoke(user_question)
    else:
        response = interpreter_chain.invoke(user_question)
    
    return response

# %%
import re
def extract_code_blocks(markdown_text):
    code_blocks = []
    pattern = r"```(?P<language>\w*)\n(?P<code>[\s\S]*?)```"
    matches = re.finditer(pattern, markdown_text)
    for match in matches:
        language = match.group("language")
        code = match.group("code").strip()
        code_blocks.append({"language": language, "code": code})
    return code_blocks

# %%
def execute_code(code_str):
    print(code_str)
    try:
        exec(code_str)
        return None  # No error
    except Exception as e:
        return str(e)

# %%
response = ask_intelligent_assistant('''
    What led to the Pacers beating the Knicks?
    ''')
print(response)
code_output=ask_intelligent_assistant(response, code=True)
print(code_output)
match = re.search(r"```python(.*?)```", code_output, re.DOTALL)
code_to_run = match.group(1).strip() if match else code_str.strip()
execute_code(code_to_run)
# Out:
# As a business analyst, I've evaluated your request to understand what led to the Pacers beating the Knicks, based on the provided HTML file. To effectively answer this, a clear visualization of the game's progression is essential.
#
# ### 1. Best Visualization
#
# The best visualization to understand the game's flow and identify critical turning points is a **Line Chart showing the cumulative score for both teams over the course of the game.**
#
# **Justification:**
# A line chart will clearly illustrate:
# *   Which team held the lead at any given point.
# *   When lead changes occurred.
# *   Periods of significant scoring runs by either team.
# *   The overall trajectory of the game, making it easy to see when the Pacers pulled ahead and maintained their advantage.
#
# ### 2. Data Extraction Approach for the Engineer
#
# The necessary data for this visualization is contained within the HTML file, specifically within the play-by-play table.
#
# **Extraction Method:**
# The engineer should use an HTML parsing library (e.g., BeautifulSoup in Python) to locate and extract data from the `<table>` element with the `id="pbp"`.
#
# **Specific Data Points to Extract:**
# For each row within the `pbp` table that represents a game event (excluding header rows like "1st Q" or "Time", and informational rows like "Jump ball" or "End of quarter"):
#
# 1.  **Event Index:** A sequential counter for each valid game event. This will serve as the X-axis for the line chart, representing the progression of the game. Using an event index is more reliable than time, as time resets at the start of each quarter.
# 2.  **New York Score:** The score for the New York Knicks at that specific event. This is found in the 'Score' column (the 4th column) of the `pbp` table. The score is presented as "NYK-IND" (e.g., "2-0", "35-43"). The first number should be extracted.
# 3.  **Indiana Score:** The score for the Indiana Pacers at that specific event. This is also found in the 'Score' column. The second number should be extracted.
#
# ### 3. Data Availability Confirmation
#
# Yes, the data needed for the visualization is present in the given file.
#
# *   The `pbp` table clearly lists game events chronologically.
# *   The 'Score' column within this table provides the cumulative score for both teams at each event (e.g., "2-0", "35-43", "121-130"). This is precisely what's needed for the Y-axis of the line chart.
# *   The implicit chronological order of the rows in the table allows for the creation of an "Event Index" for the X-axis.
#
# ---
#
# ### Approach for the Engineer: Purpose and Pseudo Code
#
# **Purpose of the Python Code:**
# The primary purpose of the Python code is to parse the provided HTML content, extract the chronological score progression for both teams from the play-by-play table, and structure this data into a format suitable for generating a cumulative score line chart. This data will enable a clear visual analysis of the game's momentum and scoring trends.
#
# **Pseudo Code for the Engineer:**
#
# ```
# FUNCTION extract_score_progression(html_content):
#     // Step 1: Parse the HTML content
#     LOAD html_content into an HTML parser object (e.g., using BeautifulSoup)
#
#     // Step 2: Locate the play-by-play table
#     FIND the <table> element with id="pbp"
#
#     // Step 3: Initialize data structures
#     CREATE an empty list called 'score_data_points'
#     INITIALIZE event_index = 0
#
#     // Step 4: Iterate through table rows to extract scores
#     FOR EACH row in the table (excluding the initial header rows and quarter headers):
#         // Identify and skip non-event rows or quarter headers
#         IF row contains text like "Jump ball", "End of", "1st Q", "2nd Q", "3rd Q", "4th Q":
#             CONTINUE to the next row
#
#         // Extract the score string from the 'Score' column (typically the 4th <td> element)
#         GET the text content of the 4th <td> element in the current row, let's call it 'score_string'
#
#         // Process the score string
#         IF 'score_string' is not empty AND contains '-':
#             SPLIT 'score_string' by '-' into 'nyk_score_str' and 'ind_score_str'
#             CONVERT 'nyk_score_str' to an integer 'nyk_current_score'
#             CONVERT 'ind_score_str' to an integer 'ind_current_score'
#
#             // Increment event index for each valid score point
#             INCREMENT event_index
#
#             // Store the extracted data
#             ADD a dictionary/object {
#                 'Event_Index': event_index,
#                 'NYK_Score': nyk_current_score,
#                 'IND_Score': ind_current_score
#             } to 'score_data_points'
#
#     // Step 5: Return the processed data
#     RETURN 'score_data_points'
#
# FUNCTION visualize_score_progression(score_data_points):
#     // Step 1: Prepare data for plotting
#     CREATE a DataFrame or similar structure from 'score_data_points'
#
#     // Step 2: Generate the line chart
#     USE a plotting library (e.g., Matplotlib, Seaborn, Plotly) to create a line chart:
#         X-axis: 'Event_Index'
#         Y-axis: 'Score'
#         Plot Line 1: 'NYK_Score' against 'Event_Index'
#         Plot Line 2: 'IND_Score' against 'Event_Index'
#
#     // Step 3: Add chart enhancements
#     SET chart title: "NBA Game Score Progression: Knicks vs Pacers (May 27, 2025)"
#     SET X-axis label: "Game Event Progression"
#     SET Y-axis label: "Cumulative Score"
#     ADD a legend to distinguish between Knicks and Pacers scores
#     ENSURE appropriate styling for readability (e.g., different colors for lines)
#
#     // Step 4: Display or save the chart
#     DISPLAY the chart
# END FUNCTION
#
# // Main execution flow
# html_content = READ the provided HTML file
# processed_data = extract_score_progression(html_content)
# visualize_score_progression(processed_data)
# ```
#
# ---
#
# ### Business Analysis: What led to the Pacers beating the Knicks?
#
# Based on the structure of the provided play-by-play data and the expected score progression visualization, here's an analysis of what likely led to the Pacers' victory:
#
# The final score of 130-121 in favor of the Indiana Pacers indicates a relatively high-scoring game where the Pacers maintained a consistent offensive edge. The visualization of cumulative scores over time would reveal the precise moments of momentum shifts, but the play-by-play table already provides strong indicators:
#
# 1.  **Early Pacers Lead and Sustained Advantage:**
#     *   The Pacers took an early lead in the first quarter (e.g., 2-3, 5-6, 7-8, 7-11, 9-13, 9-16). This initial surge set the tone for the game.
#     *   They maintained this lead through the first quarter, ending it up by 8 points (35-43).
#     *   While the Knicks managed to tie the game at points in the second quarter (e.g., 51-51, 56-56, 60-60, 63-63), the Pacers consistently regained and extended their lead, ending the half up by 5 (64-69).
#     *   The third quarter saw the Pacers further solidify their lead, finishing the quarter up by 11 points (91-102). This period was crucial for them to create a comfortable buffer.
#     *   They continued to hold a significant lead throughout the fourth quarter, ultimately winning by 9 points (121-130).
#
# 2.  **Consistent Scoring and Offensive Efficiency by Pacers:**
#     *   The Pacers' ability to consistently score, often in response to Knicks' baskets or after defensive stops, prevented the Knicks from building significant momentum.
#     *   The play-by-play shows multiple instances of Pacers players making 2-pt and 3-pt jump shots, layups, and dunks, often assisted, indicating good ball movement and shot creation.
#     *   Players like T. Haliburton and P. Siakam appear frequently in scoring plays, suggesting they were key offensive contributors.
#
# 3.  **Knicks' Scoring Droughts and Turnovers:**
#     *   While the Knicks did score, there are indications of periods where their offense stalled. For example, after a Knicks score at 3:43.0 in Q1 (30-31), they didn't score again until 2:19.0 (31-37), indicating a scoring drought.
#     *   The play-by-play also notes several turnovers by Knicks players (e.g., O. Anunoby's "step out of bounds," J. Hart's "bad pass," J. Brunson's "back court" and "lost ball," M. Bridges' "bad pass," K. Towns' "offensive foul"). These turnovers gifted possessions to the Pacers, allowing them to extend their lead without the Knicks getting a shot off.
#
# In summary, the Pacers won by establishing an early lead and consistently maintaining or extending it throughout the game, driven by their offensive efficiency and capitalizing on Knicks' turnovers and scoring lulls. The line chart visualization would vividly confirm these trends, showing the Pacers' score line consistently above the Knicks' and diverging further in key quarters.
# ```python
# import pandas as pd
# from bs4 import BeautifulSoup
# import matplotlib.pyplot as plt
#
# # Assume HTML_FILE_PATH is already defined and points to the HTML file
# # Example: HTML_FILE_PATH = "path/to/your/game_data.html"
#
# # Load the HTML content from the file
# with open(HTML_FILE_PATH, encoding="utf-8") as f:
#     html_content = f.read()
#
# # Parse the HTML content
# soup = BeautifulSoup(html_content, "lxml")
#
# # Locate the play-by-play table
# pbp_table = soup.find("table", id="pbp")
#
# score_data_points = []
# event_index = 0
#
# if pbp_table:
#     rows = pbp_table.find_all("tr")
#     for row in rows:
#         # Skip header rows (identified by 'thead' class)
#         if "thead" in row.get("class", []):
#             continue
#
#         # Get all td elements in the row
#         cols = row.find_all("td")
#
#         # A valid score event row should have at least 4 columns,
#         # and the 4th column (index 3) should contain the score string.
#         if len(cols) >= 4:
#             score_cell = cols[3]
#             score_string = score_cell.get_text(strip=True)
#
#             # Check if the score string is in the expected "NYK-IND" format
#             if '-' in score_string and score_string.count('-') == 1:
#                 try:
#                     nyk_score_str, ind_score_str = score_string.split('-')
#                     nyk_current_score = int(nyk_score_str)
#                     ind_current_score = int(ind_score_str)
#
#                     # Increment event index for each valid score point
#                     event_index += 1
#
#                     # Store the extracted data
#                     score_data_points.append({
#                         'Event_Index': event_index,
#                         'NYK_Score': nyk_current_score,
#                         'IND_Score': ind_current_score
#                     })
#                 except ValueError:
#                     # Skip if score string cannot be converted to integers
#                     continue
#             # Rows like "Jump ball" or "End of quarter" will not have a score string
#             # in the 4th column, so they will be skipped by the '-' check.
# else:
#     print("Play-by-play table with id='pbp' not found.")
#
# # Create a DataFrame from the extracted data
# df = pd.DataFrame(score_data_points)
#
# # Generate the line chart
# plt.figure(figsize=(12, 7))
# plt.plot(df['Event_Index'].values, df['NYK_Score'].values, label='New York Knicks', color='blue')
# plt.plot(df['Event_Index'].values, df['IND_Score'].values, label='Indiana Pacers', color='orange')
#
# # Add chart enhancements
# plt.title('NBA Game Score Progression: Knicks vs Pacers (May 27, 2025)')
# plt.xlabel('Game Event Progression')
# plt.ylabel('Cumulative Score')
# plt.legend()
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout() # Adjust layout to prevent labels from overlapping
# plt.show()
# ```
# import pandas as pd
# from bs4 import BeautifulSoup
# import matplotlib.pyplot as plt
#
# # Assume HTML_FILE_PATH is already defined and points to the HTML file
# # Example: HTML_FILE_PATH = "path/to/your/game_data.html"
#
# # Load the HTML content from the file
# with open(HTML_FILE_PATH, encoding="utf-8") as f:
#     html_content = f.read()
#
# # Parse the HTML content
# soup = BeautifulSoup(html_content, "lxml")
#
# # Locate the play-by-play table
# pbp_table = soup.find("table", id="pbp")
#
# score_data_points = []
# event_index = 0
#
# if pbp_table:
#     rows = pbp_table.find_all("tr")
#     for row in rows:
#         # Skip header rows (identified by 'thead' class)
#         if "thead" in row.get("class", []):
#             continue
#
#         # Get all td elements in the row
#         cols = row.find_all("td")
#
#         # A valid score event row should have at least 4 columns,
#         # and the 4th column (index 3) should contain the score string.
#         if len(cols) >= 4:
#             score_cell = cols[3]
#             score_string = score_cell.get_text(strip=True)
#
#             # Check if the score string is in the expected "NYK-IND" format
#             if '-' in score_string and score_string.count('-') == 1:
#                 try:
#                     nyk_score_str, ind_score_str = score_string.split('-')
#                     nyk_current_score = int(nyk_score_str)
#                     ind_current_score = int(ind_score_str)
#
#                     # Increment event index for each valid score point
#                     event_index += 1
#
#                     # Store the extracted data
#                     score_data_points.append({
#                         'Event_Index': event_index,
#                         'NYK_Score': nyk_current_score,
#                         'IND_Score': ind_current_score
#                     })
#                 except ValueError:
#                     # Skip if score string cannot be converted to integers
#                     continue
#             # Rows like "Jump ball" or "End of quarter" will not have a score string
#             # in the 4th column, so they will be skipped by the '-' check.
# else:
#     print("Play-by-play table with id='pbp' not found.")
#
# # Create a DataFrame from the extracted data
# df = pd.DataFrame(score_data_points)
#
# # Generate the line chart
# plt.figure(figsize=(12, 7))
# plt.plot(df['Event_Index'].values, df['NYK_Score'].values, label='New York Knicks', color='blue')
# plt.plot(df['Event_Index'].values, df['IND_Score'].values, label='Indiana Pacers', color='orange')
#
# # Add chart enhancements
# plt.title('NBA Game Score Progression: Knicks vs Pacers (May 27, 2025)')
# plt.xlabel('Game Event Progression')
# plt.ylabel('Cumulative Score')
# plt.legend()
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout() # Adjust layout to prevent labels from overlapping
# plt.show()

# %%
def make_error_section(error_msg, prev_code):
    if error_msg:
        return f"Previous attempt failed with error:\n{error_msg}\nPlease fix the Python code above. The previous code was: ```python {prev_code} ```"
    else:
        return ""

# %%
def execute_code(code_str):
    print(code_str)
    try:
        exec(code_str)
        return None  # No error
    except Exception as e:
        return str(e)

# %%
question = '''
    What led to the Pacers beating the Knicks?
    '''
MAX_ATTEMPTS = 3

attempt = 0
error_msg = None
code_to_run = None

while attempt < MAX_ATTEMPTS:
    # Compose the error section for the prompt
    error_section = make_error_section(error_msg, code_to_run)

    # (Re)build your prompt with any error message
    interpreter_prompt = PromptTemplate.from_template(interpreter_template)
    interpreter_chain = (
        {
            "raw_html_source": RunnableLambda(lambda x: raw_html_content),
            "question": RunnablePassthrough(),
            "error_section": RunnableLambda(lambda x: error_section)
        }
        | interpreter_prompt
        | LLM
        | StrOutputParser()
    )

    code_str = interpreter_chain.invoke(question)
    print('Output: ', code_str)
    # If LLM returns full markdown, extract just code
    import re
    match = re.search(r"```python(.*?)```", code_str, re.DOTALL)
    code_to_run = match.group(1).strip() if match else code_str.strip()
    error_msg = execute_code(code_to_run)
    if not error_msg:
        print('Working Code: ', code_to_run)
        exec(code_to_run)
        print("Execution SUCCESS!")
        break
    else:
        print(f"Attempt {attempt+1} failed with error: {error_msg}")
        attempt += 1

if error_msg:
    print(f"All {MAX_ATTEMPTS} attempts failed. Last error: {error_msg}")
# Out:
# Output:  As a business analyst, I've interpreted your request to understand the game's dynamics and identify the key factors that led to the Indiana Pacers' victory over the New York Knicks. The most effective way to visualize this is through a **Score Progression Line Chart**, which will clearly illustrate how the score evolved over time for both teams, highlighting periods of dominance, lead changes, and scoring runs.
#
# The provided HTML file contains a detailed play-by-play (`pbp`) table, which is precisely what we need. This table includes timestamps and the cumulative score at each event, making it ideal for constructing our score progression chart.
#
# ---
#
# ### **Purpose of the Visualization**
#
# The primary purpose of this visualization is to provide a clear, chronological overview of the game's scoring. By plotting the scores of both the New York Knicks and the Indiana Pacers against elapsed game time, we can:
#
# 1.  **Identify Lead Changes:** Easily see when one team took the lead and how frequently the lead changed hands.
# 2.  **Observe Scoring Runs:** Pinpoint periods where one team went on a significant scoring run, creating or extending their lead.
# 3.  **Understand Momentum Shifts:** Visually track the ebb and flow of the game, revealing which team controlled the pace and scoring at different stages.
# 4.  **Highlight Decisive Moments:** Clearly show when the Pacers established and maintained their winning margin, providing a data-driven answer to "What led to the Pacers beating the Knicks?".
#
# In this specific game, the visualization is expected to show the Pacers establishing an early lead and largely maintaining it throughout the game, despite some brief ties by the Knicks. This consistent scoring and control over the lead would be the primary factor in their victory.
#
# ### **Approach for the Engineer**
#
# The engineer should implement a Python script using `BeautifulSoup` for HTML parsing, `pandas` for data manipulation, and `matplotlib` for plotting.
#
# **Pseudo Code:**
#
# ```
# 1. Initialize empty lists: `elapsed_times`, `knicks_scores`, `pacers_scores`.
# 2. Initialize `current_quarter` to 0 and `base_time_offset` to 0 (in seconds).
# 3. Parse the HTML content using BeautifulSoup to find the table with `id="pbp"`.
# 4. Iterate through each row (`<tr>`) of the `pbp` table:
#     a. Check if the row is a quarter header (e.g., "1st Q", "2nd Q"). These rows have `class='thead'` and a `<th>` with `colspan='6'`.
#         i. If it's a quarter header, increment `current_quarter`.
#         ii. If `current_quarter` is greater than 1, update `base_time_offset` by adding 12 minutes (720 seconds) for each completed quarter.
#         iii. Continue to the next row (skip processing this header row as data).
#     b. Skip the column header rows within each quarter (these also have `class='thead'` but contain column names like "Time", "New York", etc.).
#     c. For data rows:
#         i. Extract the `time_str` from the first column (`<td>` at index 0).
#         ii. Extract the `score_str` from the fourth column (`<td>` at index 3).
#         iii. If `score_str` contains a hyphen (indicating a valid score, e.g., "10-5"):
#             1. Parse `time_str` (e.g., "11:36.0") into minutes and seconds. Convert seconds to an integer (ignore milliseconds).
#             2. Calculate `time_in_quarter_remaining` = `minutes * 60 + seconds`.
#             3. Calculate `elapsed_time_in_quarter` = `(12 * 60) - time_in_quarter_remaining`.
#             4. Calculate `total_elapsed_seconds` = `base_time_offset + elapsed_time_in_quarter`.
#             5. Parse `score_str` into `knicks_score` and `pacers_score` integers.
#             6. Append `total_elapsed_seconds`, `knicks_score`, and `pacers_score` to their respective lists.
# 5. Create a Pandas DataFrame from the collected `elapsed_times`, `knicks_scores`, and `pacers_scores` lists.
# 6. Generate the line chart using Matplotlib:
#     a. Plot `knicks_scores` against `elapsed_times`.
#     b. Plot `pacers_scores` against `elapsed_times`.
#     c. Add a title, x-axis label ("Elapsed Time (seconds)"), y-axis label ("Score"), and a legend to distinguish the teams.
#     d. Add a grid for better readability.
#     e. Ensure the layout is tight to prevent labels from overlapping.
#     f. Display the plot.
# ```
#
# ---
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# from bs4 import BeautifulSoup
#
# # Assume HTML_FILE_PATH is an existing variable pointing to the HTML file
# # and html_content will be pre-populated with the HTML content.
# # For demonstration, we'll load it here as per instructions for the engineer.
# with open(HTML_FILE_PATH, encoding="utf-8") as f:
#     soup = BeautifulSoup(f, "lxml")
#
# # Find the play-by-play table
# table = soup.find('table', {'id': 'pbp'})
#
# # Data storage
# elapsed_times = []
# knicks_scores = []
# pacers_scores = []
#
# current_quarter = 0
# base_time_offset = 0 # in seconds, for continuous time axis
#
# if table:
#     for row in table.find_all('tr'):
#         # Check if it's a quarter header (e.g., "1st Q", "2nd Q")
#         if 'thead' in row.get('class', []) and row.find('th', colspan='6'):
#             quarter_text = row.find('th', colspan='6').get_text(strip=True)
#             if '1st Q' in quarter_text:
#                 current_quarter = 1
#                 base_time_offset = 0
#             elif '2nd Q' in quarter_text:
#                 current_quarter = 2
#                 base_time_offset = 1 * 12 * 60 # 1 full quarter (12 minutes)
#             elif '3rd Q' in quarter_text:
#                 current_quarter = 3
#                 base_time_offset = 2 * 12 * 60 # 2 full quarters
#             elif '4th Q' in quarter_text:
#                 current_quarter = 4
#                 base_time_offset = 3 * 12 * 60 # 3 full quarters
#             continue # Skip to next row, as this is not a data row
#
#         # Skip the column headers within each quarter (e.g., "Time", "New York")
#         if 'thead' in row.get('class', []) and row.find('th', text='Time'):
#             continue
#
#         cols = row.find_all(['td', 'th'])
#         # Ensure enough columns for Time (index 0) and Score (index 3)
#         if len(cols) >= 4:
#             time_str = cols[0].get_text(strip=True)
#             score_cell = cols[3] # Score column is the 4th column (index 3)
#             score_str = score_cell.get_text(strip=True)
#
#             # Only process rows that have a valid score in the score column
#             if '-' in score_str:
#                 try:
#                     # Parse time (e.g., "11:36.0" -> 11 minutes, 36 seconds)
#                     minutes, seconds_float = map(float, time_str.split(':'))
#                     seconds = int(seconds_float) # Convert to int, ignoring milliseconds
#
#                     time_in_quarter_remaining = minutes * 60 + seconds
#                     elapsed_time_in_quarter = (12 * 60) - time_in_quarter_remaining
#                     total_elapsed_seconds = base_time_offset + elapsed_time_in_quarter
#
#                     # Parse score (e.g., "2-0" -> Knicks 2, Pacers 0)
#                     nyk_score, ind_score = map(int, score_str.split('-'))
#
#                     elapsed_times.append(total_elapsed_seconds)
#                     knicks_scores.append(nyk_score)
#                     pacers_scores.append(ind_score)
#                 except ValueError:
#                     # Skip rows where time or score parsing fails (e.g., non-numeric data)
#                     continue
#
# # Create a Pandas DataFrame
# df = pd.DataFrame({
#     'Elapsed Time (seconds)': elapsed_times,
#     'Knicks Score': knicks_scores,
#     'Pacers Score': pacers_scores
# })
#
# # Create the score progression line chart
# plt.figure(figsize=(12, 7))
# plt.plot(df['Elapsed Time (seconds)'], df['Knicks Score'], label='New York Knicks', color='blue', linewidth=2)
# plt.plot(df['Elapsed Time (seconds)'], df['Pacers Score'], label='Indiana Pacers', color='orange', linewidth=2)
#
# plt.title('2025 NBA Eastern Conference Finals Game 4: Score Progression', fontsize=16)
# plt.xlabel('Elapsed Time (seconds)', fontsize=12)
# plt.ylabel('Score', fontsize=12)
# plt.legend(fontsize=10)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# ```
# import pandas as pd
# import matplotlib.pyplot as plt
# from bs4 import BeautifulSoup
#
# # Assume HTML_FILE_PATH is an existing variable pointing to the HTML file
# # and html_content will be pre-populated with the HTML content.
# # For demonstration, we'll load it here as per instructions for the engineer.
# with open(HTML_FILE_PATH, encoding="utf-8") as f:
#     soup = BeautifulSoup(f, "lxml")
#
# # Find the play-by-play table
# table = soup.find('table', {'id': 'pbp'})
#
# # Data storage
# elapsed_times = []
# knicks_scores = []
# pacers_scores = []
#
# current_quarter = 0
# base_time_offset = 0 # in seconds, for continuous time axis
#
# if table:
#     for row in table.find_all('tr'):
#         # Check if it's a quarter header (e.g., "1st Q", "2nd Q")
#         if 'thead' in row.get('class', []) and row.find('th', colspan='6'):
#             quarter_text = row.find('th', colspan='6').get_text(strip=True)
#             if '1st Q' in quarter_text:
#                 current_quarter = 1
#                 base_time_offset = 0
#             elif '2nd Q' in quarter_text:
#                 current_quarter = 2
#                 base_time_offset = 1 * 12 * 60 # 1 full quarter (12 minutes)
#             elif '3rd Q' in quarter_text:
#                 current_quarter = 3
#                 base_time_offset = 2 * 12 * 60 # 2 full quarters
#             elif '4th Q' in quarter_text:
#                 current_quarter = 4
#                 base_time_offset = 3 * 12 * 60 # 3 full quarters
#             continue # Skip to next row, as this is not a data row
#
#         # Skip the column headers within each quarter (e.g., "Time", "New York")
#         if 'thead' in row.get('class', []) and row.find('th', text='Time'):
#             continue
#
#         cols = row.find_all(['td', 'th'])
#         # Ensure enough columns for Time (index 0) and Score (index 3)
#         if len(cols) >= 4:
#             time_str = cols[0].get_text(strip=True)
#             score_cell = cols[3] # Score column is the 4th column (index 3)
#             score_str = score_cell.get_text(strip=True)
#
#             # Only process rows that have a valid score in the score column
#             if '-' in score_str:
#                 try:
#                     # Parse time (e.g., "11:36.0" -> 11 minutes, 36 seconds)
#                     minutes, seconds_float = map(float, time_str.split(':'))
#                     seconds = int(seconds_float) # Convert to int, ignoring milliseconds
#
#                     time_in_quarter_remaining = minutes * 60 + seconds
#                     elapsed_time_in_quarter = (12 * 60) - time_in_quarter_remaining
#                     total_elapsed_seconds = base_time_offset + elapsed_time_in_quarter
#
#                     # Parse score (e.g., "2-0" -> Knicks 2, Pacers 0)
#                     nyk_score, ind_score = map(int, score_str.split('-'))
#
#                     elapsed_times.append(total_elapsed_seconds)
#                     knicks_scores.append(nyk_score)
#                     pacers_scores.append(ind_score)
#                 except ValueError:
#                     # Skip rows where time or score parsing fails (e.g., non-numeric data)
#                     continue
#
# # Create a Pandas DataFrame
# df = pd.DataFrame({
#     'Elapsed Time (seconds)': elapsed_times,
#     'Knicks Score': knicks_scores,
#     'Pacers Score': pacers_scores
# })
#
# # Create the score progression line chart
# plt.figure(figsize=(12, 7))
# plt.plot(df['Elapsed Time (seconds)'], df['Knicks Score'], label='New York Knicks', color='blue', linewidth=2)
# plt.plot(df['Elapsed Time (seconds)'], df['Pacers Score'], label='Indiana Pacers', color='orange', linewidth=2)
#
# plt.title('2025 NBA Eastern Conference Finals Game 4: Score Progression', fontsize=16)
# plt.xlabel('Elapsed Time (seconds)', fontsize=12)
# plt.ylabel('Score', fontsize=12)
# plt.legend(fontsize=10)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# Attempt 1 failed with error: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.
# Output:  As a business analyst, I've interpreted your request to understand the game's dynamics and identify the key factors that led to the Indiana Pacers' victory over the New York Knicks. The most effective way to visualize this is through a **Score Progression Line Chart**, which will clearly illustrate how the score evolved over time for both teams, highlighting periods of dominance, lead changes, and scoring runs.
#
# The provided HTML file contains a detailed play-by-play (`pbp`) table, which is precisely what we need. This table includes timestamps and the cumulative score at each event, making it ideal for constructing our score progression chart.
#
# ---
#
# ### **Purpose of the Visualization**
#
# The primary purpose of this visualization is to provide a clear, chronological overview of the game's scoring. By plotting the scores of both the New York Knicks and the Indiana Pacers against elapsed game time, we can:
#
# 1.  **Identify Lead Changes:** Easily see when one team took the lead and how frequently the lead changed hands.
# 2.  **Observe Scoring Runs:** Pinpoint periods where one team went on a significant scoring run, creating or extending their lead.
# 3.  **Understand Momentum Shifts:** Visually track the ebb and flow of the game, revealing which team controlled the pace and scoring at different stages.
# 4.  **Highlight Decisive Moments:** Clearly show when the Pacers established and maintained their winning margin, providing a data-driven answer to "What led to the Pacers beating the Knicks?".
#
# In this specific game, the visualization is expected to show the Pacers establishing an early lead and largely maintaining it throughout the game, despite some brief ties by the Knicks. This consistent scoring and control over the lead would be the primary factor in their victory.
#
# ### **Approach for the Engineer**
#
# The engineer should implement a Python script using `BeautifulSoup` for HTML parsing, `pandas` for data manipulation, and `matplotlib` for plotting.
#
# **Pseudo Code:**
#
# ```
# 1. Initialize empty lists: `elapsed_times`, `knicks_scores`, `pacers_scores`.
# 2. Initialize `current_quarter` to 0 and `base_time_offset` to 0 (in seconds).
# 3. Parse the HTML content using BeautifulSoup to find the table with `id="pbp"`.
# 4. Iterate through each row (`<tr>`) of the `pbp` table:
#     a. Check if the row is a quarter header (e.g., "1st Q", "2nd Q"). These rows have `class='thead'` and a `<th>` with `colspan='6'`.
#         i. If it's a quarter header, increment `current_quarter`.
#         ii. If `current_quarter` is greater than 1, update `base_time_offset` by adding 12 minutes (720 seconds) for each completed quarter.
#         iii. Continue to the next row (skip processing this header row as data).
#     b. Skip the column header rows within each quarter (these also have `class='thead'` but contain column names like "Time", "New York", etc.).
#     c. For data rows:
#         i. Extract the `time_str` from the first column (`<td>` at index 0).
#         ii. Extract the `score_str` from the fourth column (`<td>` at index 3).
#         iii. If `score_str` contains a hyphen (indicating a valid score, e.g., "10-5"):
#             1. Parse `time_str` (e.g., "11:36.0") into minutes and seconds. Convert seconds to an integer (ignore milliseconds).
#             2. Calculate `time_in_quarter_remaining` = `minutes * 60 + seconds`.
#             3. Calculate `elapsed_time_in_quarter` = `(12 * 60) - time_in_quarter_remaining`.
#             4. Calculate `total_elapsed_seconds` = `base_time_offset + elapsed_time_in_quarter`.
#             5. Parse `score_str` into `knicks_score` and `pacers_score` integers.
#             6. Append `total_elapsed_seconds`, `knicks_score`, and `pacers_score` to their respective lists.
# 5. Create a Pandas DataFrame from the collected `elapsed_times`, `knicks_scores`, and `pacers_scores` lists.
# 6. Generate the line chart using Matplotlib:
#     a. Plot `knicks_scores` against `elapsed_times`.
#     b. Plot `pacers_scores` against `elapsed_times`.
#     c. Add a title, x-axis label ("Elapsed Time (seconds)"), y-axis label ("Score"), and a legend to distinguish the teams.
#     d. Add a grid for better readability.
#     e. Ensure the layout is tight to prevent labels from overlapping.
#     f. Display the plot.
# ```
#
# ---
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# from bs4 import BeautifulSoup
#
# # Assume HTML_FILE_PATH is an existing variable pointing to the HTML file
# # and html_content will be pre-populated with the HTML content.
# # For demonstration, we'll load it here as per instructions for the engineer.
# with open(HTML_FILE_PATH, encoding="utf-8") as f:
#     soup = BeautifulSoup(f, "lxml")
#
# # Find the play-by-play table
# table = soup.find('table', {'id': 'pbp'})
#
# # Data storage
# elapsed_times = []
# knicks_scores = []
# pacers_scores = []
#
# current_quarter = 0
# base_time_offset = 0 # in seconds, for continuous time axis
#
# if table:
#     for row in table.find_all('tr'):
#         # Check if it's a quarter header (e.g., "1st Q", "2nd Q")
#         if 'thead' in row.get('class', []) and row.find('th', colspan='6'):
#             quarter_text = row.find('th', colspan='6').get_text(strip=True)
#             if '1st Q' in quarter_text:
#                 current_quarter = 1
#                 base_time_offset = 0
#             elif '2nd Q' in quarter_text:
#                 current_quarter = 2
#                 base_time_offset = 1 * 12 * 60 # 1 full quarter (12 minutes)
#             elif '3rd Q' in quarter_text:
#                 current_quarter = 3
#                 base_time_offset = 2 * 12 * 60 # 2 full quarters
#             elif '4th Q' in quarter_text:
#                 current_quarter = 4
#                 base_time_offset = 3 * 12 * 60 # 3 full quarters
#             continue # Skip to next row, as this is not a data row
#
#         # Skip the column headers within each quarter (e.g., "Time", "New York")
#         if 'thead' in row.get('class', []) and row.find('th', text='Time'):
#             continue
#
#         cols = row.find_all(['td', 'th'])
#         # Ensure enough columns for Time (index 0) and Score (index 3)
#         if len(cols) >= 4:
#             time_str = cols[0].get_text(strip=True)
#             score_cell = cols[3] # Score column is the 4th column (index 3)
#             score_str = score_cell.get_text(strip=True)
#
#             # Only process rows that have a valid score in the score column
#             if '-' in score_str:
#                 try:
#                     # Parse time (e.g., "11:36.0" -> 11 minutes, 36 seconds)
#                     minutes, seconds_float = map(float, time_str.split(':'))
#                     seconds = int(seconds_float) # Convert to int, ignoring milliseconds
#
#                     time_in_quarter_remaining = minutes * 60 + seconds
#                     elapsed_time_in_quarter = (12 * 60) - time_in_quarter_remaining
#                     total_elapsed_seconds = base_time_offset + elapsed_time_in_quarter
#
#                     # Parse score (e.g., "2-0" -> Knicks 2, Pacers 0)
#                     nyk_score, ind_score = map(int, score_str.split('-'))
#
#                     elapsed_times.append(total_elapsed_seconds)
#                     knicks_scores.append(nyk_score)
#                     pacers_scores.append(ind_score)
#                 except ValueError:
#                     # Skip rows where time or score parsing fails (e.g., non-numeric data)
#                     continue
#
# # Create a Pandas DataFrame
# df = pd.DataFrame({
#     'Elapsed Time (seconds)': elapsed_times,
#     'Knicks Score': knicks_scores,
#     'Pacers Score': pacers_scores
# })
#
# # Create the score progression line chart
# plt.figure(figsize=(12, 7))
# plt.plot(df['Elapsed Time (seconds)'], df['Knicks Score'], label='New York Knicks', color='blue', linewidth=2)
# plt.plot(df['Elapsed Time (seconds)'], df['Pacers Score'], label='Indiana Pacers', color='orange', linewidth=2)
#
# plt.title('2025 NBA Eastern Conference Finals Game 4: Score Progression', fontsize=16)
# plt.xlabel('Elapsed Time (seconds)', fontsize=12)
# plt.ylabel('Score', fontsize=12)
# plt.legend(fontsize=10)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# ```
# import pandas as pd
# import matplotlib.pyplot as plt
# from bs4 import BeautifulSoup
#
# # Assume HTML_FILE_PATH is an existing variable pointing to the HTML file
# # and html_content will be pre-populated with the HTML content.
# # For demonstration, we'll load it here as per instructions for the engineer.
# with open(HTML_FILE_PATH, encoding="utf-8") as f:
#     soup = BeautifulSoup(f, "lxml")
#
# # Find the play-by-play table
# table = soup.find('table', {'id': 'pbp'})
#
# # Data storage
# elapsed_times = []
# knicks_scores = []
# pacers_scores = []
#
# current_quarter = 0
# base_time_offset = 0 # in seconds, for continuous time axis
#
# if table:
#     for row in table.find_all('tr'):
#         # Check if it's a quarter header (e.g., "1st Q", "2nd Q")
#         if 'thead' in row.get('class', []) and row.find('th', colspan='6'):
#             quarter_text = row.find('th', colspan='6').get_text(strip=True)
#             if '1st Q' in quarter_text:
#                 current_quarter = 1
#                 base_time_offset = 0
#             elif '2nd Q' in quarter_text:
#                 current_quarter = 2
#                 base_time_offset = 1 * 12 * 60 # 1 full quarter (12 minutes)
#             elif '3rd Q' in quarter_text:
#                 current_quarter = 3
#                 base_time_offset = 2 * 12 * 60 # 2 full quarters
#             elif '4th Q' in quarter_text:
#                 current_quarter = 4
#                 base_time_offset = 3 * 12 * 60 # 3 full quarters
#             continue # Skip to next row, as this is not a data row
#
#         # Skip the column headers within each quarter (e.g., "Time", "New York")
#         if 'thead' in row.get('class', []) and row.find('th', text='Time'):
#             continue
#
#         cols = row.find_all(['td', 'th'])
#         # Ensure enough columns for Time (index 0) and Score (index 3)
#         if len(cols) >= 4:
#             time_str = cols[0].get_text(strip=True)
#             score_cell = cols[3] # Score column is the 4th column (index 3)
#             score_str = score_cell.get_text(strip=True)
#
#             # Only process rows that have a valid score in the score column
#             if '-' in score_str:
#                 try:
#                     # Parse time (e.g., "11:36.0" -> 11 minutes, 36 seconds)
#                     minutes, seconds_float = map(float, time_str.split(':'))
#                     seconds = int(seconds_float) # Convert to int, ignoring milliseconds
#
#                     time_in_quarter_remaining = minutes * 60 + seconds
#                     elapsed_time_in_quarter = (12 * 60) - time_in_quarter_remaining
#                     total_elapsed_seconds = base_time_offset + elapsed_time_in_quarter
#
#                     # Parse score (e.g., "2-0" -> Knicks 2, Pacers 0)
#                     nyk_score, ind_score = map(int, score_str.split('-'))
#
#                     elapsed_times.append(total_elapsed_seconds)
#                     knicks_scores.append(nyk_score)
#                     pacers_scores.append(ind_score)
#                 except ValueError:
#                     # Skip rows where time or score parsing fails (e.g., non-numeric data)
#                     continue
#
# # Create a Pandas DataFrame
# df = pd.DataFrame({
#     'Elapsed Time (seconds)': elapsed_times,
#     'Knicks Score': knicks_scores,
#     'Pacers Score': pacers_scores
# })
#
# # Create the score progression line chart
# plt.figure(figsize=(12, 7))
# plt.plot(df['Elapsed Time (seconds)'], df['Knicks Score'], label='New York Knicks', color='blue', linewidth=2)
# plt.plot(df['Elapsed Time (seconds)'], df['Pacers Score'], label='Indiana Pacers', color='orange', linewidth=2)
#
# plt.title('2025 NBA Eastern Conference Finals Game 4: Score Progression', fontsize=16)
# plt.xlabel('Elapsed Time (seconds)', fontsize=12)
# plt.ylabel('Score', fontsize=12)
# plt.legend(fontsize=10)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# Attempt 2 failed with error: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.
# Output:  As a business analyst, I've interpreted your request to understand the game's dynamics and identify the key factors that led to the Indiana Pacers' victory over the New York Knicks. The most effective way to visualize this is through a **Score Progression Line Chart**, which will clearly illustrate how the score evolved over time for both teams, highlighting periods of dominance, lead changes, and scoring runs.
#
# The provided HTML file contains a detailed play-by-play (`pbp`) table, which is precisely what we need. This table includes timestamps and the cumulative score at each event, making it ideal for constructing our score progression chart.
#
# ---
#
# ### **Purpose of the Visualization**
#
# The primary purpose of this visualization is to provide a clear, chronological overview of the game's scoring. By plotting the scores of both the New York Knicks and the Indiana Pacers against elapsed game time, we can:
#
# 1.  **Identify Lead Changes:** Easily see when one team took the lead and how frequently the lead changed hands.
# 2.  **Observe Scoring Runs:** Pinpoint periods where one team went on a significant scoring run, creating or extending their lead.
# 3.  **Understand Momentum Shifts:** Visually track the ebb and flow of the game, revealing which team controlled the pace and scoring at different stages.
# 4.  **Highlight Decisive Moments:** Clearly show when the Pacers established and maintained their winning margin, providing a data-driven answer to "What led to the Pacers beating the Knicks?".
#
# In this specific game, the visualization is expected to show the Pacers establishing an early lead and largely maintaining it throughout the game, despite some brief ties by the Knicks. This consistent scoring and control over the lead would be the primary factor in their victory.
#
# ### **Approach for the Engineer**
#
# The engineer should implement a Python script using `BeautifulSoup` for HTML parsing, `pandas` for data manipulation, and `matplotlib` for plotting.
#
# **Pseudo Code:**
#
# ```
# 1. Initialize empty lists: `elapsed_times`, `knicks_scores`, `pacers_scores`.
# 2. Initialize `current_quarter` to 0 and `base_time_offset` to 0 (in seconds).
# 3. Parse the HTML content using BeautifulSoup to find the table with `id="pbp"`.
# 4. Iterate through each row (`<tr>`) of the `pbp` table:
#     a. Check if the row is a quarter header (e.g., "1st Q", "2nd Q"). These rows have `class='thead'` and a `<th>` with `colspan='6'`.
#         i. If it's a quarter header, increment `current_quarter`.
#         ii. If `current_quarter` is greater than 1, update `base_time_offset` by adding 12 minutes (720 seconds) for each completed quarter.
#         iii. Continue to the next row (skip processing this header row as data).
#     b. Skip the column header rows within each quarter (these also have `class='thead'` but contain column names like "Time", "New York", etc.).
#     c. For data rows:
#         i. Extract the `time_str` from the first column (`<td>` at index 0).
#         ii. Extract the `score_str` from the fourth column (`<td>` at index 3).
#         iii. If `score_str` contains a hyphen (indicating a valid score, e.g., "10-5"):
#             1. Parse `time_str` (e.g., "11:36.0") into minutes and seconds. Convert seconds to an integer (ignore milliseconds).
#             2. Calculate `time_in_quarter_remaining` = `minutes * 60 + seconds`.
#             3. Calculate `elapsed_time_in_quarter` = `(12 * 60) - time_in_quarter_remaining`.
#             4. Calculate `total_elapsed_seconds` = `base_time_offset + elapsed_time_in_quarter`.
#             5. Parse `score_str` into `knicks_score` and `pacers_score` integers.
#             6. Append `total_elapsed_seconds`, `knicks_score`, and `pacers_score` to their respective lists.
# 5. Create a Pandas DataFrame from the collected `elapsed_times`, `knicks_scores`, and `pacers_scores` lists.
# 6. Generate the line chart using Matplotlib:
#     a. Plot `knicks_scores` against `elapsed_times`.
#     b. Plot `pacers_scores` against `elapsed_times`.
#     c. Add a title, x-axis label ("Elapsed Time (seconds)"), y-axis label ("Score"), and a legend to distinguish the teams.
#     d. Add a grid for better readability.
#     e. Ensure the layout is tight to prevent labels from overlapping.
#     f. Display the plot.
# ```
#
# ---
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# from bs4 import BeautifulSoup
#
# # Assume HTML_FILE_PATH is an existing variable pointing to the HTML file
# # and html_content will be pre-populated with the HTML content.
# # For demonstration, we'll load it here as per instructions for the engineer.
# with open(HTML_FILE_PATH, encoding="utf-8") as f:
#     soup = BeautifulSoup(f, "lxml")
#
# # Find the play-by-play table
# table = soup.find('table', {'id': 'pbp'})
#
# # Data storage
# elapsed_times = []
# knicks_scores = []
# pacers_scores = []
#
# current_quarter = 0
# base_time_offset = 0 # in seconds, for continuous time axis
#
# if table:
#     for row in table.find_all('tr'):
#         # Check if it's a quarter header (e.g., "1st Q", "2nd Q")
#         if 'thead' in row.get('class', []) and row.find('th', colspan='6'):
#             quarter_text = row.find('th', colspan='6').get_text(strip=True)
#             if '1st Q' in quarter_text:
#                 current_quarter = 1
#                 base_time_offset = 0
#             elif '2nd Q' in quarter_text:
#                 current_quarter = 2
#                 base_time_offset = 1 * 12 * 60 # 1 full quarter (12 minutes)
#             elif '3rd Q' in quarter_text:
#                 current_quarter = 3
#                 base_time_offset = 2 * 12 * 60 # 2 full quarters
#             elif '4th Q' in quarter_text:
#                 current_quarter = 4
#                 base_time_offset = 3 * 12 * 60 # 3 full quarters
#             continue # Skip to next row, as this is not a data row
#
#         # Skip the column headers within each quarter (e.g., "Time", "New York")
#         if 'thead' in row.get('class', []) and row.find('th', text='Time'):
#             continue
#
#         cols = row.find_all(['td', 'th'])
#         # Ensure enough columns for Time (index 0) and Score (index 3)
#         if len(cols) >= 4:
#             time_str = cols[0].get_text(strip=True)
#             score_cell = cols[3] # Score column is the 4th column (index 3)
#             score_str = score_cell.get_text(strip=True)
#
#             # Only process rows that have a valid score in the score column
#             if '-' in score_str:
#                 try:
#                     # Parse time (e.g., "11:36.0" -> 11 minutes, 36 seconds)
#                     minutes, seconds_float = map(float, time_str.split(':'))
#                     seconds = int(seconds_float) # Convert to int, ignoring milliseconds
#
#                     time_in_quarter_remaining = minutes * 60 + seconds
#                     elapsed_time_in_quarter = (12 * 60) - time_in_quarter_remaining
#                     total_elapsed_seconds = base_time_offset + elapsed_time_in_quarter
#
#                     # Parse score (e.g., "2-0" -> Knicks 2, Pacers 0)
#                     nyk_score, ind_score = map(int, score_str.split('-'))
#
#                     elapsed_times.append(total_elapsed_seconds)
#                     knicks_scores.append(nyk_score)
#                     pacers_scores.append(ind_score)
#                 except ValueError:
#                     # Skip rows where time or score parsing fails (e.g., non-numeric data)
#                     continue
#
# # Create a Pandas DataFrame
# df = pd.DataFrame({
#     'Elapsed Time (seconds)': elapsed_times,
#     'Knicks Score': knicks_scores,
#     'Pacers Score': pacers_scores
# })
#
# # Create the score progression line chart
# plt.figure(figsize=(12, 7))
# plt.plot(df['Elapsed Time (seconds)'], df['Knicks Score'], label='New York Knicks', color='blue', linewidth=2)
# plt.plot(df['Elapsed Time (seconds)'], df['Pacers Score'], label='Indiana Pacers', color='orange', linewidth=2)
#
# plt.title('2025 NBA Eastern Conference Finals Game 4: Score Progression', fontsize=16)
# plt.xlabel('Elapsed Time (seconds)', fontsize=12)
# plt.ylabel('Score', fontsize=12)
# plt.legend(fontsize=10)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# ```
# import pandas as pd
# import matplotlib.pyplot as plt
# from bs4 import BeautifulSoup
#
# # Assume HTML_FILE_PATH is an existing variable pointing to the HTML file
# # and html_content will be pre-populated with the HTML content.
# # For demonstration, we'll load it here as per instructions for the engineer.
# with open(HTML_FILE_PATH, encoding="utf-8") as f:
#     soup = BeautifulSoup(f, "lxml")
#
# # Find the play-by-play table
# table = soup.find('table', {'id': 'pbp'})
#
# # Data storage
# elapsed_times = []
# knicks_scores = []
# pacers_scores = []
#
# current_quarter = 0
# base_time_offset = 0 # in seconds, for continuous time axis
#
# if table:
#     for row in table.find_all('tr'):
#         # Check if it's a quarter header (e.g., "1st Q", "2nd Q")
#         if 'thead' in row.get('class', []) and row.find('th', colspan='6'):
#             quarter_text = row.find('th', colspan='6').get_text(strip=True)
#             if '1st Q' in quarter_text:
#                 current_quarter = 1
#                 base_time_offset = 0
#             elif '2nd Q' in quarter_text:
#                 current_quarter = 2
#                 base_time_offset = 1 * 12 * 60 # 1 full quarter (12 minutes)
#             elif '3rd Q' in quarter_text:
#                 current_quarter = 3
#                 base_time_offset = 2 * 12 * 60 # 2 full quarters
#             elif '4th Q' in quarter_text:
#                 current_quarter = 4
#                 base_time_offset = 3 * 12 * 60 # 3 full quarters
#             continue # Skip to next row, as this is not a data row
#
#         # Skip the column headers within each quarter (e.g., "Time", "New York")
#         if 'thead' in row.get('class', []) and row.find('th', text='Time'):
#             continue
#
#         cols = row.find_all(['td', 'th'])
#         # Ensure enough columns for Time (index 0) and Score (index 3)
#         if len(cols) >= 4:
#             time_str = cols[0].get_text(strip=True)
#             score_cell = cols[3] # Score column is the 4th column (index 3)
#             score_str = score_cell.get_text(strip=True)
#
#             # Only process rows that have a valid score in the score column
#             if '-' in score_str:
#                 try:
#                     # Parse time (e.g., "11:36.0" -> 11 minutes, 36 seconds)
#                     minutes, seconds_float = map(float, time_str.split(':'))
#                     seconds = int(seconds_float) # Convert to int, ignoring milliseconds
#
#                     time_in_quarter_remaining = minutes * 60 + seconds
#                     elapsed_time_in_quarter = (12 * 60) - time_in_quarter_remaining
#                     total_elapsed_seconds = base_time_offset + elapsed_time_in_quarter
#
#                     # Parse score (e.g., "2-0" -> Knicks 2, Pacers 0)
#                     nyk_score, ind_score = map(int, score_str.split('-'))
#
#                     elapsed_times.append(total_elapsed_seconds)
#                     knicks_scores.append(nyk_score)
#                     pacers_scores.append(ind_score)
#                 except ValueError:
#                     # Skip rows where time or score parsing fails (e.g., non-numeric data)
#                     continue
#
# # Create a Pandas DataFrame
# df = pd.DataFrame({
#     'Elapsed Time (seconds)': elapsed_times,
#     'Knicks Score': knicks_scores,
#     'Pacers Score': pacers_scores
# })
#
# # Create the score progression line chart
# plt.figure(figsize=(12, 7))
# plt.plot(df['Elapsed Time (seconds)'], df['Knicks Score'], label='New York Knicks', color='blue', linewidth=2)
# plt.plot(df['Elapsed Time (seconds)'], df['Pacers Score'], label='Indiana Pacers', color='orange', linewidth=2)
#
# plt.title('2025 NBA Eastern Conference Finals Game 4: Score Progression', fontsize=16)
# plt.xlabel('Elapsed Time (seconds)', fontsize=12)
# plt.ylabel('Score', fontsize=12)
# plt.legend(fontsize=10)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# Attempt 3 failed with error: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.
# All 3 attempts failed. Last error: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# Assume HTML_FILE_PATH is an existing variable for the HTML file, e.g.:
# HTML_FILE_PATH = "path/to/your/game_data.html"

# Load the HTML content from the file
with open(HTML_FILE_PATH, encoding="utf-8") as f:
    soup = BeautifulSoup(f, "lxml")

# Define NBA quarter length in seconds
quarter_duration_seconds = 12 * 60

# Initialize quarter lengths and cumulative start times
quarter_lengths = {1: quarter_duration_seconds, 2: quarter_duration_seconds, 3: quarter_duration_seconds, 4: quarter_duration_seconds}
cumulative_quarter_start_time = {1: 0}
for q in range(2, 5):
    cumulative_quarter_start_time[q] = cumulative_quarter_start_time[q-1] + quarter_lengths[q-1]

current_quarter = 0
game_times = []
knicks_scores = []
pacers_scores = []

# Find the play-by-play table
pbp_table = soup.find("table", id="pbp")

if pbp_table:
    # Iterate through each row in the table body
    for row in pbp_table.find_all("tr"):
        # Check if the row is a quarter header
        if 'class' in row.attrs and 'thead' in row.attrs and row.get('id') and row['id'].startswith('q'):
            try:
                current_quarter = int(row['id'][1:])
            except ValueError:
                continue # Skip if quarter ID is not a valid number
            continue # Skip to the next row as this is just a header

        # Process only play rows within a valid quarter
        if current_quarter > 0:
            time_cell = row.find("th", {"data-stat": "Time"})
            score_cell = row.find("td", {"data-stat": "Score"})

            if time_cell and score_cell and time_cell.text.strip() and score_cell.text.strip():
                time_str = time_cell.text.strip()
                score_str = score_cell.text.strip()

                # Parse time (MM:SS.X)
                try:
                    minutes, seconds_decimal = map(float, time_str.split(':'))
                    seconds_remaining_in_quarter = (minutes * 60) + seconds_decimal
                except ValueError:
                    continue # Skip if time format is unexpected

                # Calculate elapsed time for the current play
                # Time in PBP is time remaining in quarter, so convert to elapsed time in quarter
                elapsed_time_in_current_quarter = quarter_lengths[current_quarter] - seconds_remaining_in_quarter
                
                # Add current quarter elapsed time to total elapsed time from previous quarters
                total_elapsed_time_for_play = cumulative_quarter_start_time[current_quarter] + elapsed_time_in_current_quarter
                
                # Parse scores (NYK-IND)
                try:
                    nyk_score, ind_score = map(int, score_str.split('-'))
                except ValueError:
                    continue # Skip if score format is unexpected

                # Store data points
                game_times.append(total_elapsed_time_for_play)
                knicks_scores.append(nyk_score)
                pacers_scores.append(ind_score)

# Create a Pandas DataFrame
df = pd.DataFrame({
    'GameTime': game_times,
    'KnicksScore': knicks_scores,
    'PacersScore': pacers_scores
})

# Sort by GameTime to ensure correct line progression
df = df.sort_values(by='GameTime').reset_index(drop=True)

# In case multiple events occur at the exact same timestamp, keep the last (most updated) score
df = df.drop_duplicates(subset=['GameTime'], keep='last')

# Visualization
plt.figure(figsize=(12, 7))
plt.plot(df['GameTime'].values, df['KnicksScore'].values, label='New York Knicks', color='blue', marker='o', markersize=3, linewidth=2)
plt.plot(df['GameTime'].values, df['PacersScore'].values, label='Indiana Pacers', color='orange', marker='x', markersize=3, linewidth=2)

plt.title('2025 NBA Eastern Conference Finals Game 4: Score Progression')
plt.xlabel('Elapsed Game Time (Seconds)')
plt.ylabel('Cumulative Score')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# Assume HTML_FILE_PATH is an existing variable for the HTML file,
# e.g., HTML_FILE_PATH = "path/to/your/game_data.html"
# The script will load the HTML content from this file.

# Data extraction
elapsed_game_seconds = []
knicks_cumulative_scores = []
pacers_cumulative_scores = []

SECONDS_PER_QUARTER = 12 * 60  # 12 minutes per NBA quarter
current_quarter_offset_seconds = 0
current_quarter_number = 0

# Load the HTML content from the file
# As per instructions, assume HTML_FILE_PATH is set and load content into soup.
with open(HTML_FILE_PATH, encoding="utf-8") as f:
    soup = BeautifulSoup(f, "lxml")

pbp_table = soup.find("table", id="pbp")

if pbp_table:
    for row in pbp_table.find_all("tr"):
        # Check if the row is a quarter header
        if 'class' in row.attrs and 'thead' in row['class'] and row.get('id', '').startswith('q'):
            current_quarter_number += 1
            # Update the offset for the start of the new quarter (if not the first quarter)
            if current_quarter_number > 1:
                current_quarter_offset_seconds = (current_quarter_number - 1) * SECONDS_PER_QUARTER
            continue  # Skip processing this header row as a play event

        # Attempt to find all td elements in the row
        tds = row.find_all("td")

        # Ensure there are enough columns and the score column has content
        if len(tds) < 4:
            continue

        time_cell = tds[0]
        score_cell = tds[3]

        time_str = time_cell.get_text().strip()
        score_text = score_cell.get_text().strip()

        # Skip rows without a valid time or score format
        if not time_str or ':' not in time_str or not score_text or '-' not in score_text:
            continue

        try:
            # Parse minutes and seconds from the time string (e.g., "11:36.0")
            minutes_str, seconds_str = time_str.split(':')
            minutes_in_quarter = int(minutes_str)
            seconds_in_quarter = int(float(seconds_str)) # Handle ".0"

            # Calculate seconds elapsed within the current quarter (time counts down)
            seconds_elapsed_in_current_quarter = SECONDS_PER_QUARTER - (minutes_in_quarter * 60 + seconds_in_quarter)

            # Calculate the absolute time from the start of the game
            absolute_time_in_seconds = current_quarter_offset_seconds + seconds_elapsed_in_current_quarter
            elapsed_game_seconds.append(absolute_time_in_seconds)

            # Split the score string into Knicks and Pacers scores (e.g., "121-130")
            knicks_score_str, pacers_score_str = score_text.split('-')
            knicks_score = int(knicks_score_str)
            pacers_score = int(pacers_score_str)
            knicks_cumulative_scores.append(knicks_score)
            pacers_cumulative_scores.append(pacers_score)

        except ValueError:
            # If parsing fails for time or score, skip this row
            continue
else:
    print("Error: Play-by-play table with id='pbp' not found in the HTML content.")
    # Exit or handle the error as appropriate for your application
    exit()

# Create a Pandas DataFrame from the extracted data
game_data = pd.DataFrame({
    "time_in_seconds": elapsed_game_seconds,
    "knicks_score": knicks_cumulative_scores,
    "pacers_score": pacers_cumulative_scores
})

# Visualization: Dual-Line Chart
plt.figure(figsize=(14, 8)) # Adjust figure size for better readability

# Plot the Knicks' score progression
plt.plot(game_data["time_in_seconds"], game_data["knicks_score"], 
         label="New York Knicks Score", color="blue", linewidth=2)

# Plot the Pacers' score progression
plt.plot(game_data["time_in_seconds"], game_data["pacers_score"], 
         label="Indiana Pacers Score", color="gold", linewidth=2)

# Set chart title and axis labels
plt.title("Game 4 Score Progression: New York Knicks vs. Indiana Pacers", fontsize=16)
plt.xlabel("Elapsed Game Time (Seconds)", fontsize=12)
plt.ylabel("Cumulative Score", fontsize=12)

# Add a legend to distinguish the lines
plt.legend(fontsize=10)

# Add vertical lines to mark quarter boundaries for better context
# Assuming 4 quarters of 12 minutes (720 seconds) each
quarter_boundaries = [SECONDS_PER_QUARTER, 2 * SECONDS_PER_QUARTER, 3 * SECONDS_PER_QUARTER]
for i, q_time in enumerate(quarter_boundaries):
    # Only draw if the boundary is within the actual game duration
    if q_time < game_data["time_in_seconds"].max():
        plt.axvline(x=q_time, color='gray', linestyle='--', linewidth=0.8, 
                    label=f'End of Q{i+1}' if i == 0 else "") # Label only first boundary to avoid clutter

plt.grid(True, linestyle=':', alpha=0.7) # Add a grid for easier reading
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 91
#      88 plt.figure(figsize=(14, 8)) # Adjust figure size for better readability
#      90 # Plot the Knicks' score progression
# ---> 91 plt.plot(game_data["time_in_seconds"], game_data["knicks_score"],
#      92          label="New York Knicks Score", color="blue", linewidth=2)
#      94 # Plot the Pacers' score progression
#      95 plt.plot(game_data["time_in_seconds"], game_data["pacers_score"],
#      96          label="Indiana Pacers Score", color="gold", linewidth=2)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:487, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     484         kw[prop_name] = val
#     486 if len(xy) == 2:
# --> 487     x = _check_1d(xy[0])
#     488     y = _check_1d(xy[1])
#     489 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\cbook\__init__.py:1327, in _check_1d(x)
#    1321 with warnings.catch_warnings(record=True) as w:
#    1322     warnings.filterwarnings(
#    1323         "always",
#    1324         category=Warning,
#    1325         message='Support for multi-dimensional indexing')
# -> 1327     ndim = x[:, None].ndim
#    1328     # we have definitely hit a pandas index or series object
#    1329     # cast to a numpy array.
#    1330     if len(w) > 0:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1072, in Series.__getitem__(self, key)
#    1069     key = np.asarray(key, dtype=bool)
#    1070     return self._get_rows_with_mask(key)
# -> 1072 return self._get_with(key)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1082, in Series._get_with(self, key)
#    1077     raise TypeError(
#    1078         "Indexing a Series with DataFrame is not "
#    1079         "supported, use the appropriate DataFrame column"
#    1080     )
#    1081 elif isinstance(key, tuple):
# -> 1082     return self._get_values_tuple(key)
#    1084 elif not is_list_like(key):
#    1085     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1086     return self.loc[key]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1122, in Series._get_values_tuple(self, key)
#    1117 if com.any_none(*key):
#    1118     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1119     #  see tests.series.timeseries.test_mpl_compat_hack
#    1120     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1121     result = np.asarray(self._values[key])
# -> 1122     disallow_ndim_indexing(result)
#    1123     return result
#    1125 if not isinstance(self.index, MultiIndex):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexers\utils.py:341, in disallow_ndim_indexing(result)
#     333 """
#     334 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     335
#    (...)
#     338 in GH#30588.
#     339 """
#     340 if np.ndim(result) > 1:
# --> 341     raise ValueError(
#     342         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343         "supported. Convert to a numpy array before indexing instead."
#     344     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.
